# %%
import pandas as pd;
import numpy as np;
import matplotlib.pyplot as plt;
import seaborn as sb;

# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
import pandas as pd
from sqlalchemy import create_engine

server = 'DESKTOP-35V1L7L\SQLEXPRESS' 
database = 'Sales_table'

connection_string = (
    f"mssql+pyodbc://@{'DESKTOP-35V1L7L\SQLEXPRESS'}/{'Sales_table'}"
    "?driver=ODBC+Driver+17+for+SQL+Server"
    "&trusted_connection=yes"
)

engine = create_engine(connection_string)
# Out:
# <>:4: SyntaxWarning: invalid escape sequence '\S'
# <>:8: SyntaxWarning: invalid escape sequence '\S'
# <>:4: SyntaxWarning: invalid escape sequence '\S'
# <>:8: SyntaxWarning: invalid escape sequence '\S'
# C:\Users\pc\AppData\Local\Temp\ipykernel_3888\3713993519.py:4: SyntaxWarning: invalid escape sequence '\S'
#   server = 'DESKTOP-35V1L7L\SQLEXPRESS'
# C:\Users\pc\AppData\Local\Temp\ipykernel_3888\3713993519.py:8: SyntaxWarning: invalid escape sequence '\S'
#   f"mssql+pyodbc://@{'DESKTOP-35V1L7L\SQLEXPRESS'}/{'Sales_table'}"

# %%
df = pd.read_sql('SELECT * from Sales_table_1', con=engine)
df.head()
# Out:
#      year   category sub-category  \
# 0     NaN       None         None
# 1  2013.0  Furniture    Bookcases
# 2  2013.0  Furniture    Bookcases
# 3  2013.0  Furniture    Bookcases
# 4  2013.0  Furniture    Bookcases
#
#                                         Product Name  Total_sales  \
# 0                                               None          NaN
# 1  Atlantic Metals Mobile 3-Shelf Bookcases, Cust...     521.9600
# 2  Atlantic Metals Mobile 4-Shelf Bookcases, Cust...    1573.4880
# 3                            Bestar Classic Bookcase     672.9327
# 4   Bush Andora Bookcase, Maple/Graphite Gray Finish     305.9745
#
#    Total_revenue  total_quantity_sold  total_discount
# 0            NaN                  NaN             NaN
# 1      -250.5408                  4.0            0.50
# 2       196.6860                  7.0            0.20
# 3      -217.9782                 11.0            0.97
# 4        25.1979                  3.0            0.15

# %%
df = df.drop(0)
df.head()
# Out:
#      year   category sub-category  \
# 1  2013.0  Furniture    Bookcases
# 2  2013.0  Furniture    Bookcases
# 3  2013.0  Furniture    Bookcases
# 4  2013.0  Furniture    Bookcases
# 5  2013.0  Furniture    Bookcases
#
#                                         Product Name  Total_sales  \
# 1  Atlantic Metals Mobile 3-Shelf Bookcases, Cust...     521.9600
# 2  Atlantic Metals Mobile 4-Shelf Bookcases, Cust...    1573.4880
# 3                            Bestar Classic Bookcase     672.9327
# 4   Bush Andora Bookcase, Maple/Graphite Gray Finish     305.9745
# 5  Bush Heritage Pine Collection 5-Shelf Bookcase...    1811.5930
#
#    Total_revenue  total_quantity_sold  total_discount
# 1      -250.5408                  4.0            0.50
# 2       196.6860                  7.0            0.20
# 3      -217.9782                 11.0            0.97
# 4        25.1979                  3.0            0.15
# 5         7.0490                 16.0            0.45

# %%
plt.bar(df['category'],df['Total_sales'],color = 'skyblue')
plt.xlabel('category')
plt.ylabel('Total_sales')
plt.tight_layout()
plt.show()

# %%
plt.bar(df['category'],df['Total_revenue'],color = 'skyblue')
plt.xlabel('category')
plt.ylabel('Total_revenue')
plt.tight_layout()
plt.show()

# %%
df_top_products = df.sort_values(by='Total_sales',ascending=False).head(3)
plt.bar(df_top_products['Product Name'],df_top_products['Total_revenue'],color='orange')
plt.xlabel('Product Name')
plt.ylabel('Total_revenue')
plt.tight_layout()
plt.show()
